# %%
import pandas as pd 
import numpy as np
# Out:
# C:\Users\Sharon\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('zillow.csv')
df.head()
# Out:
#    RegionID  SizeRank    RegionName RegionType  StateName     2000-01-31  \
# 0         9         0    California      state        NaN  173446.527272
# 1        54         1         Texas      state        NaN   98444.846662
# 2        14         2       Florida      state        NaN  107908.136131
# 3        43         3      New York      state        NaN  114954.967001
# 4        47         4  Pennsylvania      state        NaN   89715.146150
#
#       2000-02-29     2000-03-31     2000-04-30     2000-05-31  ...  \
# 0  173995.852438  174765.887938  176421.911006  178362.851122  ...
# 1   98502.096514   98522.268274   98645.951801   98713.935808  ...
# 2  108164.392249  108455.497513  109032.853215  109631.850759  ...
# 3  115216.802424  115490.628944  116123.985919  116820.217234  ...
# 4   89900.134312   90075.879582   90431.298428   90804.977845  ...
#
#       2024-03-31     2024-04-30     2024-05-31     2024-06-30     2024-07-31  \
# ...

# %%
# Replace null values in monthly columns with their column-specific average
monthly_columns = df.columns[5:]  # Select all monthly columns (from 5th column onward)

# Replace NaN values with column-specific mean
df[monthly_columns] = df[monthly_columns].apply(lambda col: col.fillna(col.mean()), axis=0)

# Confirm that null values have been replaced
null_counts = df[monthly_columns].isnull().sum()

# Display results to verify
null_counts
# Out:
# 2000-01-31    0
# 2000-02-29    0
# 2000-03-31    0
# 2000-04-30    0
# 2000-05-31    0
#              ..
# 2024-08-31    0
# 2024-09-30    0
# 2024-10-31    0
# 2024-11-30    0
# 2024-12-31    0
# Length: 300, dtype: int64

# %%
df=df.drop('StateName',axis=1)

# %%
df=df.drop('RegionType',axis=1)

# %%
df.head()
# Out:
#    RegionID  SizeRank    RegionName     2000-01-31     2000-02-29  \
# 0         9         0    California  173446.527272  173995.852438
# 1        54         1         Texas   98444.846662   98502.096514
# 2        14         2       Florida  107908.136131  108164.392249
# 3        43         3      New York  114954.967001  115216.802424
# 4        47         4  Pennsylvania   89715.146150   89900.134312
#
#       2000-03-31     2000-04-30     2000-05-31     2000-06-30     2000-07-31  \
# 0  174765.887938  176421.911006  178362.851122  180458.506775  182683.346787
# 1   98522.268274   98645.951801   98713.935808   98796.603585   98842.008671
# 2  108455.497513  109032.853215  109631.850759  110239.107263  110855.501518
# 3  115490.628944  116123.985919  116820.217234  117588.852140  118187.381049
# 4   90075.879582   90431.298428   90804.977845   91181.125549   91576.522556
#
#    ...     2024-03-31     2024-04-30     2024-05-31     2024-06-30  \
# ...

# %%
df.columns
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', '2000-01-31', '2000-02-29',
#        '2000-03-31', '2000-04-30', '2000-05-31', '2000-06-30', '2000-07-31',
#        ...
#        '2024-03-31', '2024-04-30', '2024-05-31', '2024-06-30', '2024-07-31',
#        '2024-08-31', '2024-09-30', '2024-10-31', '2024-11-30', '2024-12-31'],
#       dtype='object', length=303)

# %%
df.isnull().sum()
# Out:
# RegionID      0
# SizeRank      0
# RegionName    0
# 2000-01-31    0
# 2000-02-29    0
#              ..
# 2024-08-31    0
# 2024-09-30    0
# 2024-10-31    0
# 2024-11-30    0
# 2024-12-31    0
# Length: 303, dtype: int64

# %%
# Define the desired file path
file_path = r"D:\Data Analyst (Resume Datasets)\Excel Datasets\zillow_dataset.csv"

# Save the cleaned dataset to the specified path
df.to_csv(file_path, index=False)

print(f"Cleaned dataset saved to: {file_path}")
# Out:
# Cleaned dataset saved to: D:\Data Analyst (Resume Datasets)\Excel Datasets\zillow_dataset.csv
